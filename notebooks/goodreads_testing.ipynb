# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
from matplotlib.backends.backend_pdf import PdfPages
import mysql.connector

# %%
#from sklearn.linear_model import LinearRegression

# %%
config = {
  'user': 'book_data',
  'password': 'book_data',
  'host': '127.0.0.1',
  'database': 'BookData',
  'raise_on_warnings': True
}

cnx = mysql.connector.connect(**config)

goodreads_choice_awards = pd.read_sql("Select * from goodreadschoiceawards", cnx)
goodreads_100k = pd.read_sql("Select * from goodreads100k", cnx)
cnx.close()

# %%
goodreads_choice_awards
# Out:
#                                                  title  \
# 0                                            Divergent
# 1                                          Shadowfever
# 2                                 A Dance with Dragons
# 3                                City of Fallen Angels
# 4                                           Bossypants
# ...                                                ...
# 4545  Mo' Meta Blues: The World According to Questlove
# 4546                                  My Beloved World
# 4547                                      Coming Clean
# 4548             After Visiting Friends: A Son's Story
# 4549                                    Chanel Bonfire
#
#                         author  \
# 0                Veronica Roth
# 1           Karen Marie Moning
# 2           George R.R. Martin
# 3              Cassandra Clare
# 4                     Tina Fey
# ...                        ...
# 4545  Ahmir Questlove Thompson
# 4546           Sonia Sotomayor
# 4547       Kimberly Rae Miller
# 4548            Michael Hainey
# 4549             Wendy Lawless
#
#                                             description      bookformat  \
# 0     In Beatrice Prior's dystopian Chicago, society...       Hardcover
# 1     “Evil is a completely different creature, Mac....       Hardcover
# 2     Alternate cover edition of ASIN B004XISI4AIn t...  Kindle Edition
# 3     The Mortal War is over, and sixteen-year-old C...       Hardcover
# 4     Before Liz Lemon, before "Weekend Update," bef...  Kindle Edition
# ...                                                 ...             ...
# 4545  MO' META BLUESThe World According to Questlove...       Hardcover
# 4546  The first Latinx (Puerto Rican) and third woma...       Hardcover
# 4547  A stunning memoir about a childhood spent grow...       Hardcover
# 4548  Michael Hainey had just turned six when his un...       Hardcover
# 4549  A stunning memoir about an actress's unconvent...       Hardcover
#
#                bookedition   pages published_date  \
# 0              1st edition   487.0           None
# 1            First Edition   608.0           None
# 2                           1125.0           None
# 3            First Edition   425.0           None
# 4                            283.0           None
# ...                    ...     ...            ...
# 4545  First Edition (U.S.)   288.0           None
# 4546                         302.0           None
# 4547                         272.0           None
# 4548                         307.0           None
# 4549                         304.0           None
#
#                         publisher      reading_age lexile_measure  ...  \
# 0           Katherine Tegen Books  14 years and up         HL700L  ...
# 1                 Delacorte Press                                  ...
# 2                                                                  ...
# 3     Margaret K. McElderry Books  14 years and up         HL750L  ...
# 4                                                                  ...
# ...                           ...              ...            ...  ...
# 4545                                                               ...
# 4546                                                               ...
# 4547                                                               ...
# 4548                                                               ...
# 4549                                                               ...
#
#      genere_1_weight  genere_2_weight  genere_3_weight  genere_4_weight  \
# 0           0.328425         0.222024         0.113507         0.106666
# 1           0.211983         0.208148         0.162019         0.122214
# 2           0.702602         0.144885         0.031548         0.023312
# 3           0.337296         0.243346         0.086832         0.083956
# 4           0.304529         0.179684         0.163715         0.109603
# ...              ...              ...              ...              ...
# 4545        0.346939         0.231293         0.163265         0.119728
# 4546        0.275894         0.259638         0.163957         0.061774
# 4547        0.318627         0.312091         0.076797         0.068627
# 4548        0.374552         0.358423         0.087814         0.062724
# 4549        0.389381         0.351032         0.082596         0.053097
#
#       genere_5_weight  genere_6_weight  genere_7_weight  genere_8_weight  \
# 0            0.093449         0.064917         0.023852         0.019872
# 1            0.083031         0.078781         0.048202         0.031720
# 2            0.021093         0.017476         0.016534         0.016473
# 3            0.061511         0.049763         0.042539         0.038681
# 4            0.076105         0.057850         0.039813         0.028780
# ...               ...              ...              ...              ...
# 4545         0.039456         0.032653         0.023129         0.016327
# 4546         0.049698         0.049698         0.046447         0.046447
# 4547         0.060457         0.040850         0.037582         0.037582
# 4548         0.028674         0.019713         0.019713         0.017921
# 4549         0.032448         0.023599         0.020649         0.020649
#
#      genere_9_weight     price
# 0           0.013714  0.013574
# 1           0.030787  0.023116
# 2           0.013829  0.012249
# 3           0.030545  0.025530
# 4           0.021013  0.018908
# ...              ...       ...
# 4545        0.014966  0.012245
# 4546        0.026475  0.019972
# 4547        0.024510  0.022876
# 4548        0.017921  0.012545
# 4549        0.014749  0.011799
#
# [4550 rows x 39 columns]

# %%
goodreads_100k
# Out:
#                                                   author bookformat  \
# 0                                   Laurence M. Hauptman  Hardcover
# 1                       Charlotte Fiell,Emmanuelle Dirix  Paperback
# 2                                          Andy Anderson  Paperback
# 3                                   Carlotta R. Anderson  Hardcover
# 4                                          Jean Leveille
# ...                                                  ...        ...
# 99995                                         Simon Monk      ebook
# 99996  Tracie L. Miller-Nobles,Brenda L. Mattison,Ell...  Hardcover
# 99997                                     C. John Miller  Paperback
# 99998                                      Albert Marrin  Hardcover
# 99999                                      Marc E. Fitch      ebook
#
#                                              description  \
# 0      Reveals that several hundred thousand Indians ...
# 1      Fashion Sourcebook - 1920s is the first book i...
# 2      The seminal history and analysis of the Hungar...
# 3      "All-American Anarchist" chronicles the life a...
# 4      Aujourdâ€™hui, lâ€™oiseau nous invite Ã  sa ta...
# ...                                                  ...
# 99995  Design custom printed circuit boards with EAGL...
# 99996  Redefining tradition in learning accounting. ,...
# 99997  In these warm reflections on his own growth as...
# 99998  John Brown is a man of many legacies, from her...
# 99999  Did you know that interest in UFO research inc...
#
#                                                    genre  \
# 0      History,Military History,Civil War,American Hi...
# 1              Couture,Fashion,Historical,Art,Nonfiction
# 2                                       Politics,History
# 3                                          Labor,History
# 4
# ...                                                  ...
# 99995
# 99996
# 99997  Christianity,Evangelism,Christian,Religion,The...
# 99998  Nonfiction,History,Biography,Military History,...
# 99999                      Fantasy,Paranormal,Nonfiction
#
#                                                      img        isbn  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...  002914180X
# 1      https://i.gr-assets.com/images/S/compressed.ph...  1906863482
# 2      https://i.gr-assets.com/images/S/compressed.ph...   948984147
# 3      https://i.gr-assets.com/images/S/compressed.ph...   814327079
# 4      https://i.gr-assets.com/images/S/compressed.ph...  2761920813
# ...                                                  ...         ...
# 99995  https://i.gr-assets.com/images/S/compressed.ph...    71819266
# 99996  https://i.gr-assets.com/images/S/compressed.ph...   133251241
# 99997  https://i.gr-assets.com/images/S/compressed.ph...   875523919
# 99998  https://i.gr-assets.com/images/S/compressed.ph...   307981533
# 99999  https://i.gr-assets.com/images/S/compressed.ph...   313382077
#
#             isnb13                                               link  pages  \
# 0         9.78E+12  https://goodreads.com/book/show/1001053.Betwee...      0
# 1         9.78E+12  https://goodreads.com/book/show/10010552-fashi...    576
# 2         9.78E+12  https://goodreads.com/book/show/1001077.Hungar...    124
# 3         9.78E+12  https://goodreads.com/book/show/1001079.All_Am...    324
# 4                   https://goodreads.com/book/show/10010880-les-o...    177
# ...            ...                                                ...    ...
# 99995  9.78007E+12  https://goodreads.com/book/show/17320181-make-...    304
# 99996  9.78013E+12  https://goodreads.com/book/show/17320260-horng...   1645
# 99997  9.78088E+12  https://goodreads.com/book/show/173203.A_Faith...    160
# 99998  9.78031E+12  https://goodreads.com/book/show/17320669-a-vol...    256
# 99999  9.78031E+12  https://goodreads.com/book/show/17320689-paran...    398
#
#        rating  reviews                                              title  \
# 0        3.52        5  Between Two Fires: American Indians in the Civ...
# 1        4.51        6                           Fashion Sourcebook 1920s
# 2        4.15        2                                         Hungary 56
# 3        3.83        1  All-American Anarchist: Joseph A. Labadie and ...
# 4        4.00        1                              Les oiseaux gourmands
# ...       ...      ...                                                ...
# 99995    4.07        7  Make Your Own PCBs with Eagle: From Schematic ...
# 99996    4.05        1       Horngren's Financial & Managerial Accounting
# 99997    4.27       20  A Faith Worth Sharing: A Lifetime of Conversat...
# 99998    3.63       51  A Volcano Beneath the Snow: John Brown's War A...
# 99999    3.83        3  Paranormal Nation: Why America Needs Ghosts, U...
#
#        totalratings
# 0              33.0
# 1              41.0
# 2              26.0
# 3               6.0
# 4               1.0
# ...             ...
# 99995          56.0
# 99996          38.0
# 99997         122.0
# 99998         156.0
# 99999          12.0
#
# [100000 rows x 13 columns]
